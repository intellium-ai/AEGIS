# %%
from primaite.agents.gnn.gnn_agent import GNNAgent

# %%
agent = GNNAgent(training_config_path='../../config/_package_data/training/gnn.yaml', lay_down_config_path='../../config/_package_data/lay_down/lay_down_config_6_data_manipulation.yaml')
# Out:
# 2024-08-09 10:47:05,546: Using: AgentFramework.CUSTOM, AgentIdentifier.GNN, ActionType.NODE, observation_space=NODE_LINK_TABLE, Training: 8 episodes @ 256 stepsEvaluation: 8 episodes @ 256 steps
# 2024-08-09 10:47:05,594: Environment configuration loaded
# AgentIdentifier.GNN
# 2024-08-09 10:47:05,887: Welcome to the Primary-level AI Training Environment (PrimAITE) (version: 2.0.1)
# 2024-08-09 10:47:05,888: The output directory for this session is: /home/jonathan/primaite/2.0.1/sessions/2024-08-09/2024-08-09_10-47-05
# GNNPolicy(
#   (conv1): GATConv(6, 128, heads=1)
#   (linear): Linear(in_features=128, out_features=128, bias=True)
#   (linear2): Linear(in_features=128, out_features=100, bias=True)
#   (layer_norm): LayerNorm(128, affine=True, mode=graph)
# )

# %%
agent.learn()
# Out:
# 2024-08-09 10:47:08,177: Episode: 1, Average Reward: -0.04637890625000001
# 2024-08-09 10:47:10,680: Episode: 2, Average Reward: -0.043421874999999985
# 2024-08-09 10:47:13,084: Episode: 3, Average Reward: -0.0435
# 2024-08-09 10:47:15,554: Episode: 4, Average Reward: -0.045865234374999966
# 2024-08-09 10:47:18,181: Episode: 5, Average Reward: -0.04560351562499998
# 2024-08-09 10:47:20,596: Episode: 6, Average Reward: -0.044183593749999986
# 2024-08-09 10:47:22,966: Episode: 7, Average Reward: -0.04559375000000001
# 2024-08-09 10:47:25,441: Episode: 8, Average Reward: -0.04524609375000011
# 2024-08-09 10:47:27,790: Episode: 9, Average Reward: -0.046341796874999966
# 2024-08-09 10:47:30,122: Episode: 10, Average Reward: -0.046289062500000006
# 2024-08-09 10:47:32,523: Episode: 11, Average Reward: -0.04654101562499997
# 2024-08-09 10:47:34,905: Episode: 12, Average Reward: -0.046550781250000006
# 2024-08-09 10:47:37,181: Episode: 13, Average Reward: -0.04561914062499993
# ...
