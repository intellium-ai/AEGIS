# %%
from primaite.agents.sb3 import SB3Agent

# %%
agent = SB3Agent(
    training_config_path="../agents/training_configs/sb3.yaml",
    lay_down_config_path="../data//laydown_configs/lay_down_config_6_data_manipulation.yaml",
)
# Out:
# 2024-09-03 14:52:26,084: Using: AgentFramework.SB3, AgentIdentifier.A2C, ActionType.NODE, observation_space=NODE_LINK_TABLE, Training: 8 episodes @ 128 stepsEvaluation: 8 episodes @ 128 steps
# 2024-09-03 14:52:26,130: Environment configuration loaded
# 2024-09-03 14:52:28,156: Welcome to the Primary-level AI Training Environment (PrimAITE) (version: 2.0.1)
# 2024-09-03 14:52:28,157: The output directory for this session is: /home/jonathan/primaite/2.0.1/sessions/2024-09-03/2024-09-03_14-52-26

# %%
agent.learn()

# %%
agent.evaluate()
# Out:
# 2024-09-03 14:52:28,167: Beginning non-deterministic evaluation for 8 episodes @ 128 time steps...
# 2024-09-03 14:52:28,611: Episode: 1, Average Reward: -0.041964843750000015
# 2024-09-03 14:52:29,047: Episode: 2, Average Reward: -0.04339062500000002
# 2024-09-03 14:52:29,497: Episode: 3, Average Reward: -0.04448828124999995
# 2024-09-03 14:52:29,931: Episode: 4, Average Reward: -0.0478515625
# 2024-09-03 14:52:30,358: Episode: 5, Average Reward: -0.04723437500000002
# 2024-09-03 14:52:30,794: Episode: 6, Average Reward: -0.044273437500000005
# 2024-09-03 14:52:31,224: Episode: 7, Average Reward: -0.04592578125000002
# 2024-09-03 14:52:31,658: Episode: 8, Average Reward: -0.043371093749999985

# %%
agent._env.average_reward
# Out:
# -0.043371093749999985

# %%
agent.save()
