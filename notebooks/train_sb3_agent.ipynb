# %%
from primaite.agents.rllib import RLlibAgent

# %%
agent = RLlibAgent(
    training_config_path="../agents/training_configs/rllib.yaml",
    lay_down_config_path="../data//laydown_configs/lay_down_config_6_data_manipulation.yaml",
)
agent.learn()
agent._agent.save('./srv/')

agent = RLlibAgent(
    training_config_path="../agents/training_configs/rllib.yaml",
    lay_down_config_path="../data//laydown_configs/lay_down_config_3_DOS_very_basic.yaml",
)
agent._agent.load_checkpoint('./srv/checkpoint_000002/')
agent.learn()
agent._agent.save('./srv/')
# Out:
# 2024-09-19 10:26:05,356: Welcome to the Primary-level AI Training Environment (PrimAITE) (version: 2.0.1)
# 2024-09-19 10:26:05,356: The output directory for this session is: /home/jonathan/primaite/2.0.1/sessions/2024-09-19/2024-09-19_10-26-05
# 2024-09-19 10:26:13,146: Using: AgentFramework.RLLIB, DeepLearningFramework.TF2, AgentIdentifier.PPO, ActionType.NODE, observation_space=NODE_LINK_TABLE, Training: 2 episodes @ 128 stepsEvaluation: 2 episodes @ 128 steps
# 2024-09-19 10:26:13,196: Environment configuration loaded
# 2024-09-19 10:26:13,329: Beginning learning for 2 episodes @ 128 time steps...
# {'item_type': 'RED_POL', 'id': '50', 'start_step': 50, 'end_step': 50, 'targetNodeId': '1', 'initiator': 'DIRECT', 'type': 'SERVICE', 'protocol': 'UDP', 'state': 'COMPROMISED', 'sourceNodeId': 'NA', 'sourceNodeService': 'NA', 'sourceNodeServiceState': 'NA'}
# ...

# %%
agent._agent.save('./srv/')
# Out:
# './srv/checkpoint_000002'

# %%
agent.learn()
# Out:
# 2024-09-19 10:20:46,104: Beginning learning for 2 episodes @ 128 time steps...
# 2024-09-19 10:20:47,491: Finished learning

# %%
agent.save()
