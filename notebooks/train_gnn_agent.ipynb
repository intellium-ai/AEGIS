# %%
from primaite.agents.gnn_agent import GNNAgent

# %%
agent = GNNAgent(
    training_config_path="../src/primaite/config/_package_data/training/gnn.yaml",
    lay_down_config_path="../src/primaite/config/_package_data/lay_down/lay_down_config_6_data_manipulation.yaml",
)

# %%
agent.learn()
