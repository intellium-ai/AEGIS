# %%
from primaite.agents.gnn_agent import GNNAgent
import os
import pandas as pd

from primaite.common.enums import (
    NodeType,
)

# %%
lay_down='1.yaml'
lay_down_eval_rewards = []
agent = GNNAgent(
        training_config_path="../agents/training_configs/gnn.yaml",
        lay_down_config_path=f"../data/datasets/JohnTesting/{lay_down}",
    )
# Out:
# 2024-09-10 10:08:04,727: Using: AgentFramework.CUSTOM, AgentIdentifier.GNN, ActionType.NODE, observation_space=NODE_LINK_TABLE, Training: 8 episodes @ 256 stepsEvaluation: 8 episodes @ 256 steps
# 2024-09-10 10:08:04,751: Environment configuration loaded
# 2024-09-10 10:08:04,857: Welcome to the Primary-level AI Training Environment (PrimAITE) (version: 2.0.1)
# 2024-09-10 10:08:04,858: The output directory for this session is: /home/jonathan/primaite/2.0.1/sessions/2024-09-10/2024-09-10_10-08-04
# AgentIdentifier.GNN
# {'end_step': 112, 'id': '0', 'initiator': 'IER', 'item_type': 'RED_POL', 'nodeId': '3', 'protocol': 'SSH', 'sourceNodeId': '0', 'sourceNodeService': 'SSH', 'sourceNodeServiceState': 'OVERWHELMED', 'start_step': 48, 'state': 'OVERWHELMED', 'targetNodeId': '3', 'type': 'SERVICE'}
# {'end_step': 101, 'id': '1', 'initiator': 'IER', 'item_type': 'RED_POL', 'nodeId': '5', 'protocol': 'SSH', 'sourceNodeId': '2', 'sourceNodeService': 'SSH', 'sourceNodeServiceState': 'NONE', 'start_step': 95, 'state': 'NONE', 'targetNodeId': '5', 'type': 'OPERATING'}
# {'end_step': 33, 'id': '2', 'initiator': 'IER', 'item_type': 'RED_POL', 'nodeId': '5', 'protocol': 'SSH', 'sourceNodeId': '2', 'sourceNodeService': 'SSH', 'sourceNodeServiceState': 'NONE', 'start_step': 22, 'state': 'NONE', 'targetNodeId': '5', 'type': 'OS'}
# {'end_step': 122, 'id': '3', 'initiator': 'IER', 'item_type': 'RED_POL', 'nodeId': '2', 'protocol': 'SSH', 'sourceNodeId': '0', 'sourceNodeService': 'SSH', 'sourceNodeServiceState': 'GOOD', 'start_step': 57, 'state': 'GOOD', 'targetNodeId': '2', 'type': 'OS'}
# {'end_step': 105, 'id': '4', 'initiator': 'IER', 'item_type': 'RED_POL', 'nodeId': '5', 'protocol': 'SSH', 'sourceNodeId': '2', 'sourceNodeService': 'SSH', 'sourceNodeServiceState': 'ON', 'start_step': 40, 'state': 'ON', 'targetNodeId': '5', 'type': 'OPERATING'}
# GNNPolicy(
#   (conv1): GATConv(5, 128, heads=1)
#   (linear): Linear(in_features=128, out_features=128, bias=True)
#   (linear2): Linear(in_features=128, out_features=100, bias=True)
#   (layer_norm): LayerNorm(128, affine=True, mode=graph)
# )

# %%
agent._env.nodes
# Out:
# {'0': COMPUTER_1,
#  '1': COMPUTER_2,
#  '2': COMPUTER_3,
#  '3': SWITCH_1,
#  '4': COMPUTER_4,
#  '5': COMPUTER_5}

# %%
avg_ep_reward = agent.evaluate()
lay_down_eval_rewards.append(avg_ep_reward)

# %%
from primaite.network.network import Network
Network.from_env(agent._env).nodes_table()
# Out:
#           Name Hardware State Software State File System State  \
# 1     SERVER_1            OFF       PATCHING         RESTORING
# 2   COMPUTER_1        BOOTING       PATCHING         RESTORING
# 3       CCTV_1             ON              -         DESTROYED
# 4   COMPUTER_2             ON              -         DESTROYED
# 5     SWITCH_1             ON           GOOD              GOOD
# 6   COMPUTER_3             ON       PATCHING              GOOD
# 7     SWITCH_2             ON    COMPROMISED         REPAIRING
# 8   COMPUTER_4             ON       PATCHING                 -
# 9     SWITCH_3  SHUTTING_DOWN    OVERWHELMED                 -
# 10    SWITCH_4              -       PATCHING         DESTROYED
# 11    SWITCH_5             ON    OVERWHELMED                 -
#
#    HTTP Service State SSH Service State
# 1                GOOD                 -
# 2         COMPROMISED       COMPROMISED
# 3                   -                 -
# 4         OVERWHELMED                 -
# 5                   -                 -
# 6            PATCHING          PATCHING
# 7                   -                 -
# 8                GOOD                 -
# 9                   -                 -
# 10                  -                 -
# 11                  -                 -

# %%
obs = agent._env.reset()

# %%
data = agent.create_graph(obs)

# %%
data.x.shape
# Out:
# torch.Size([11, 5])

# %%
data.edge_index.shape
# Out:
# torch.Size([2, 34])

# %%
# Primaite does this inside _create_random_red_agent and fails because compters here is an empty list.
# Decide how many nodes become compromised
node_list = list(agent._env.nodes.values())
computers = [node for node in node_list if node.node_type == NodeType.COMPUTER]
computers
