# %%
from primaite.agents.aegis.gllm import GLLM
from primaite.agents.aegis.modules.openai import OpenAIClient
from primaite.agents.git_agent import GITAgent
from primaite.agents.llm.utils import network_connectivity_desc

# %%
gllm = GLLM(openai_api_key="NOPE")

# %%
# Mock a primaite graph for development
agent = GITAgent(
    training_config_path="../src/primaite/config/_package_data/training/git.yaml",
    lay_down_config_path="../src/primaite/config/_package_data/lay_down/lay_down_config_6_data_manipulation.yaml",
)
obs = agent._env.reset()
data = agent.create_graph(obs)
network_desc = network_connectivity_desc(agent._env)

# %%
questions = [
    "How many nodes are in the network?",
    "How many unique node types are there?",
    "What is the total number of node connections?",
    "What is the total number of unique services in the network?",
    "Are there any database nodes in the network?",
    "How many switches are in the network?" "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
    "How many nodes are in the network?",
]

# %%
gllm_responses, openai_responses = gllm.train(
    x=data.x,
    edge_index=data.edge_index,
    network_desc=network_desc,
    questions=questions,
)

# %%
input_ids = gllm.llm.tokenizer.batch_encode_plus(['hi', 'bye'], return_tensors='pt').input_ids

# %%
input_ids

# %%
input_ids.shape

# %%
input1 = gllm.llm.get_embeddings(token_ids=input_ids)
input2 = gllm.llm.get_embeddings(token_ids=input_ids)

# %%
input1.shape

# %%
import torch
loss_fn = torch.nn.CosineEmbeddingLoss()

# %%
torch.ones(2)

# %%
You have started to work on calculating a loss value in batches as opposed to one at a time - and then doing a backwards pass on all of this at once. May be worth a chat with stefan about the loss calculation as even with gradients nothing seems to be changing in terms of the output loss value. Is it possible that using the gradients from the embedding is not the right way to perform a loss calculation + backwards pass?

# %%
loss_fn(input1, input2, torch.ones(2))
