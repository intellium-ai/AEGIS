# %%
from primaite.agents.git_agent import GITAgent
import logging

logging.disable(logging.CRITICAL)
import os

# %%
agent = GITAgent(
    training_config_path="../agents/training_configs/git.yaml",
    lay_down_config_path="/srv/aegis-training-data/laydowns/group_1/laydowns/0-0.yaml",
    save_path="./runs/Sep13_15-54-54_ds-turing02/epoch_4-step_5000/",
)

# %%
agent.learn()

# %%
agent.evaluate()
